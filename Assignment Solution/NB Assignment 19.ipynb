# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the dataset
data = pd.read_csv(r"/Users/rahulpoojith/Documents/Excelr Datasets/Machine Learning Datasets/blogs.csv")
data
# Out:
#                                                    Data              Labels
# 0     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 1     Newsgroups: alt.atheism\nPath: cantaloupe.srv....         alt.atheism
# 2     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...         alt.atheism
# 3     Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...         alt.atheism
# 4     Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...         alt.atheism
# ...                                                 ...                 ...
# 1995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...  talk.religion.misc
# 1996  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1997  Xref: cantaloupe.srv.cs.cmu.edu talk.origins:4...  talk.religion.misc
# 1998  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....  talk.religion.misc
# 1999  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...  talk.religion.misc
#
# [2000 rows x 2 columns]

# %%
# Preprocess the text (example)
data['Data'] = data['Data'].str.lower().str.replace('[^\w\s]', '', regex=True)

data['Data']
# Out:
# 0       path cantaloupesrvcscmuedumagnesiumclubcccmued...
# 1       newsgroups altatheism\npath cantaloupesrvcscmu...
# 2       path cantaloupesrvcscmuedudasnewsharvardedunoc...
# 3       path cantaloupesrvcscmuedumagnesiumclubcccmued...
# 4       xref cantaloupesrvcscmuedu altatheism53485 tal...
#                               ...
# 1995    xref cantaloupesrvcscmuedu talkabortion120945 ...
# 1996    xref cantaloupesrvcscmuedu talkreligionmisc837...
# 1997    xref cantaloupesrvcscmuedu talkorigins41030 ta...
# 1998    xref cantaloupesrvcscmuedu talkreligionmisc836...
# 1999    xref cantaloupesrvcscmuedu sciskeptic43561 tal...
# Name: Data, Length: 2000, dtype: object

# %%
# Feature extraction
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data['Data'])
y = data['Labels']

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Create and train the model
nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
print(y_test)
# Out:
# 201     comp.os.ms-windows.misc
# 403       comp.sys.mac.hardware
# 281     comp.os.ms-windows.misc
# 633                misc.forsale
# 1307                    sci.med
#                  ...
# 476       comp.sys.mac.hardware
# 557              comp.windows.x
# 647                misc.forsale
# 1243            sci.electronics
# 1439                  sci.space
# Name: Labels, Length: 400, dtype: object

# %%
# Make predictions
y_pred = nb.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.71
# Precision: 0.8230880523167806
# Recall: 0.71
# F1-score: 0.7230251383756001

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
for index, row in data.iterrows():
    # Get the text of the blog post
    text = row['Data']

    # Analyze the sentiment using the SentimentIntensityAnalyzer
    sentiment = sia.polarity_scores(text)

    # Categorize the sentiment based on the compound score
    if sentiment['compound'] > 0.05:
        sentiment_category = 'positive'
    elif sentiment['compound'] < -0.05:
        sentiment_category = 'negative'
    else:
        sentiment_category = 'neutral'

    # Add the sentiment category to the DataFrame
    data.loc[index, 'Sentiment'] = sentiment_category

# %%
text
# Out:
# 'xref cantaloupesrvcscmuedu sciskeptic43561 talkpoliticsmisc179100 talkreligionmisc84001 misclegal61038\npath cantaloupesrvcscmuedurochesterudelgatechhowlandrestonansnetusccsutexaseduuunetirismbvlabwpafbafmilblackbirdafitafmilafterlifetecsun1descartesriggs\nfrom riggsdescartesetlarmymil bill riggs\nnewsgroups sciskeptictalkpoliticsmisctalkreligionmiscmisclegal\nsubject re whos next  mormons and jews\nmessageid 2017tecsun1tecarmymil\ndate 24 apr 93 001920 gmt\nreferences 1993apr200519029472gwwmichedu 2003tecsun1tecarmymil gerry93apr21132149onioncmuedu\nsender newstecsun1tecarmymil\nfollowupto sciskeptictalkpoliticsmisctalkreligionmiscmisclegal\norganization lnk corporation riverdale md\nlines 85\nnntppostinghost descartestecarmymil\n\n\n\ti was slightly surprised to see the guns of roston open up on me here\nbut gerry has his posting record and i have mine although im usually more \npolite than gerry is im not afraid of controversy either if this looks like\nan argument that he starte
# ...

# %%
sentiment
# Out:
# {'neg': 0.124, 'neu': 0.793, 'pos': 0.083, 'compound': -0.9894}

# %%
 data.loc[index, 'Sentiment']
# Out:
# 'negative'

# %%
sentiment_counts = data['Sentiment'].value_counts()

# %%
sentiment_counts
# Out:
# Sentiment
# positive    1309
# negative     636
# neutral       55
# Name: count, dtype: int64

# %%
print("Sentiment Distribution:")
print(sentiment_counts)
# Out:
# Sentiment Distribution:
# Sentiment
# positive    1309
# negative     636
# neutral       55
# Name: count, dtype: int64

# %% [raw]
# Implications:
#
# Based on the above sentiment distribution, we can draw the following conclusions about the content of the blog posts:
#
# Predominantly Positive Tone: The majority of the blog posts exhibit a positive sentiment. This suggests that the content is generally optimistic, encouraging, or supportive.
#
# Significant Negative Sentiment: While the positive sentiment is dominant, a considerable number of posts express negative emotions. This indicates that there are discussions or topics that evoke negative feelings or concerns.
#
# Neutral Sentiment: A smaller percentage of posts have a neutral sentiment, suggesting that they are more objective or balanced in their tone.

# %% [raw]
# Performance Metrics:
#
# Accuracy: 0.71 - This indicates that the model correctly classified 71% of the blog posts. While decent, it's not exceptionally high, suggesting room for improvement.
# Precision: 0.82 - This means that out of the posts the model predicted as positive, 82% were actually positive. This is a good indicator of the model's ability to avoid false positives.
# Recall: 0.71 - This indicates that the model correctly identified 71% of the actual positive posts. It's a balanced metric, suggesting the model doesn't miss too many positive instances.
# F1-score: 0.72 - This is a harmonic mean of precision and recall, providing a balanced measure of performance. It's slightly lower than the precision, suggesting a trade-off between precision and recall.
# Potential Challenges:
#
# Class Imbalance: If the dataset has a significant imbalance between positive and negative classes, it can affect the model's performance. Naive Bayes can be sensitive to class imbalance, leading to biased predictions.
# Feature Engineering: The choice of features and their representation can impact the model's accuracy. If the features are not informative or if the text representation is not suitable, the model may struggle to capture the nuances of sentiment.
# Model Assumptions: The Naive Bayes assumption of feature independence may not hold true in real-world text data. Correlated features can affect the model's performance.
# Data Quality: Noise, such as misspelled words or typos, can introduce errors in the classification process.
# Overfitting: If the model is too complex or the training data is limited, it may overfit to the training set and perform poorly on unseen data.
#
# Addressing Challenges:
#
# Handle Class Imbalance: Use techniques like oversampling, undersampling, or class weighting to balance the classes.
# Experiment with Different Features: Explore different text representations (e.g., TF-IDF, word embeddings) and feature selection methods to improve feature relevance.
# Consider Alternative Models: Explore other classification algorithms like Support Vector Machines (SVM) or Random Forest that may be less sensitive to feature independence.
# Improve Data Quality: Implement preprocessing steps to clean and normalize the data.
# Regularization: Use techniques like L1 or L2 regularization to prevent overfitting and improve generalization.
